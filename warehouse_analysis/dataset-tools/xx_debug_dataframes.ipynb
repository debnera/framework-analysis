# %%
import pandas as pd
df = pd.read_feather("../../data_warehouse/minimized_warehouse_6bbb//1738402069_(1.10000)/worker1.feather")
df2 = pd.read_feather("../../data_warehouse/minimized_warehouse_6bbb//1738402069_(1.10000)/intermediate/full.feather")

for c in df2.columns:
    if "worker1" in c and "container" not in c:
        print(c)
# Out:
# {"__name__":"instance:node_cpu:rate:sum","instance":"worker1"}
# {"__name__":"instance:node_network_transmit_bytes:rate:sum","instance":"worker1"}
# {"__name__":"node_quantile:kubelet_pleg_relist_duration_seconds:histogram_quantile","instance":"130.233.193.143:10250","node":"worker1","quantile":"0.5"}
# {"__name__":"node_quantile:kubelet_pleg_relist_duration_seconds:histogram_quantile","instance":"130.233.193.143:10250","node":"worker1","quantile":"0.9"}
# {"__name__":"node_quantile:kubelet_pleg_relist_duration_seconds:histogram_quantile","instance":"130.233.193.143:10250","node":"worker1","quantile":"0.99"}
# {"__name__":"instance:node_network_receive_bytes:rate:sum","instance":"worker1"}

# %%
import pandas as pd
df = pd.read_feather("../../data_warehouse/minimized_warehouse_6b//1738402069_(1.10000)/worker1.feather")
df2 = pd.read_feather("../../data_warehouse/minimized_warehouse_6b//1738402069_(1.10000)/intermediate/full.feather")

for c in df.columns:
    if "worker1" in c and "container" not in c:
        print(c)
# Out:
# {"__name__":"node_scrape_collector_duration_seconds","collector":"arp","instance":"worker1"}
# {"__name__":"node_scrape_collector_duration_seconds","collector":"bcache","instance":"worker1"}
# {"__name__":"node_scrape_collector_duration_seconds","collector":"bonding","instance":"worker1"}
# {"__name__":"node_scrape_collector_duration_seconds","collector":"conntrack","instance":"worker1"}
# {"__name__":"node_scrape_collector_duration_seconds","collector":"cpu","instance":"worker1"}
# {"__name__":"node_scrape_collector_duration_seconds","collector":"cpufreq","instance":"worker1"}
# {"__name__":"node_scrape_collector_duration_seconds","collector":"diskstats","instance":"worker1"}
# {"__name__":"node_scrape_collector_duration_seconds","collector":"dmi","instance":"worker1"}
# {"__name__":"node_scrape_collector_duration_seconds","collector":"edac","instance":"worker1"}
# {"__name__":"node_scrape_collector_duration_seconds","collector":"entropy","instance":"worker1"}
# ...

# %%
import pandas as pd
df = pd.read_feather("../../data_warehouse/minimized_warehouse_6b//1738402069_(1.10000)/worker1.feather")
df2 = pd.read_feather("../../data_warehouse/minimized_warehouse_6b//1738402069_(1.10000)/intermediate/full.feather")

for c in df2.columns:
    if "monitoring" in c:
        print(c)
# Out:
# {"__name__": "apiserver_request_sli_duration_seconds_bucket", "component": "apiserver", "container": "prometheus-adapter", "endpoint": "https", "instance": "10.213.61.2:6443", "job": "prometheus-adapter", "le": "+Inf", "namespace": "monitoring", "pod": "prometheus-adapter-6f6995c6d9-lm9kb", "service": "prometheus-adapter", "subresource": "apis", "verb": "GET"}
# {"__name__": "apiserver_request_sli_duration_seconds_bucket", "component": "apiserver", "container": "prometheus-adapter", "endpoint": "https", "instance": "10.213.61.2:6443", "job": "prometheus-adapter", "le": "0.05", "namespace": "monitoring", "pod": "prometheus-adapter-6f6995c6d9-lm9kb", "service": "prometheus-adapter", "subresource": "apis", "verb": "GET"}
# ...
