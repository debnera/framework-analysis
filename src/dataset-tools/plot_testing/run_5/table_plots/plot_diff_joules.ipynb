# %%
import pandas as pd

df = pd.read_csv("data_diff_joules.csv")

df
# Out:
#    Unnamed: 0       160       320        640       1280
# 0      yolo8n  0.165642  0.135784   0.673568   2.603084
# 1      yolo9n  0.174703  0.136223   0.682131   2.600894
# 2     yolo10n  0.167173  0.120309   0.570643   2.449582
# 3     yolo11n  0.152009  0.115960   0.572286   2.345751
# 4      yolo8s  0.270859  0.425566   1.866956   7.249903
# 5      yolo9s  0.278651  0.406514   1.833307   6.999466
# 6     yolo10s  0.249350  0.346692   1.556392   6.275852
# 7     yolo11s  0.242423  0.336378   1.541513   6.147150
# 8      yolo8m  0.575169  1.092686   4.737581  19.578121
# 9      yolo9m  0.572958  1.126932   4.905687  20.193819
# 10    yolo10m  0.485893  0.874390   3.804059  16.165795
# 11    yolo11m  0.543855  1.009459   4.370147  18.113591
# 12     yolo8l  0.978532  2.269903   9.475670  37.847339
# 13     yolo9l  0.706056  1.487743   6.408138  26.427651
# 14    yolo10l  0.808667  1.748217   7.469736  30.439940
# 15    yolo11l  0.642802  1.297588   5.562791  23.383147
# 16     yolo8x  1.375830  3.376863  14.544720  57.190587
# 17     yolo9x  1.350191  2.923540  13.275941  53.342633
# 18    yolo10x  1.018947  2.296534   9.760809  39.948090
# 19    yolo11x  1.225667  2.694787   9.666573  49.992661

# %%
df["model_name"] = df["Unnamed: 0"]

# %%
df["yolo_version"] = df["model_name"].str.extract(r'(\d+)').astype(int)
df["model_size"] = df["model_name"].str[-1]

# %%
df
# Out:
#    Unnamed: 0       160       320        640       1280 model_name  \
# 0      yolo8n  0.165642  0.135784   0.673568   2.603084     yolo8n
# 1      yolo9n  0.174703  0.136223   0.682131   2.600894     yolo9n
# 2     yolo10n  0.167173  0.120309   0.570643   2.449582    yolo10n
# 3     yolo11n  0.152009  0.115960   0.572286   2.345751    yolo11n
# 4      yolo8s  0.270859  0.425566   1.866956   7.249903     yolo8s
# 5      yolo9s  0.278651  0.406514   1.833307   6.999466     yolo9s
# 6     yolo10s  0.249350  0.346692   1.556392   6.275852    yolo10s
# 7     yolo11s  0.242423  0.336378   1.541513   6.147150    yolo11s
# 8      yolo8m  0.575169  1.092686   4.737581  19.578121     yolo8m
# 9      yolo9m  0.572958  1.126932   4.905687  20.193819     yolo9m
# 10    yolo10m  0.485893  0.874390   3.804059  16.165795    yolo10m
# 11    yolo11m  0.543855  1.009459   4.370147  18.113591    yolo11m
# 12     yolo8l  0.978532  2.269903   9.475670  37.847339     yolo8l
# 13     yolo9l  0.706056  1.487743   6.408138  26.427651     yolo9l
# 14    yolo10l  0.808667  1.748217   7.469736  30.439940    yolo10l
# 15    yolo11l  0.642802  1.297588   5.562791  23.383147    yolo11l
# 16     yolo8x  1.375830  3.376863  14.544720  57.190587     yolo8x
# 17     yolo9x  1.350191  2.923540  13.275941  53.342633     yolo9x
# 18    yolo10x  1.018947  2.296534   9.760809  39.948090    yolo10x
# 19    yolo11x  1.225667  2.694787   9.666573  49.992661    yolo11x
#
#     yolo_version model_size
# 0              8          n
# 1              9          n
# 2             10          n
# 3             11          n
# 4              8          s
# 5              9          s
# 6             10          s
# 7             11          s
# 8              8          m
# 9              9          m
# 10            10          m
# 11            11          m
# 12             8          l
# 13             9          l
# 14            10          l
# 15            11          l
# 16             8          x
# 17             9          x
# 18            10          x
# 19            11          x

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("data_diff_joules.csv")
df["model_name"] = df["Unnamed: 0"]
df["yolo_version"] = df["model_name"].str.extract(r'(\d+)').astype(int)
df["model_size"] = df["model_name"].str[-1]

# Melt the dataframe
df_melted = df.melt(id_vars=["model_size", "yolo_version"], value_vars=["160", "320", "640", "1280"],
                    var_name="resolution", value_name="value")

# Create a new column combining resolution and yolo_version
df_melted['res_yolo'] = df_melted['resolution'] + '-' + df_melted['yolo_version'].astype(str)

# Pivot the dataframe for heatmap
heatmap_data = df_melted.pivot_table(index='model_size', columns='res_yolo', values='value')

# Sort columns first by resolution then by yolo_version
sorted_cols = sorted(heatmap_data.columns, key=lambda x: (int(x.split('-')[0]), int(x.split('-')[1])))
heatmap_data = heatmap_data[sorted_cols]

# Sort the model sizes
model_size_order = ["n", "s", "m", "l", "x"]
model_size_order.reverse()
heatmap_data = heatmap_data.loc[model_size_order]

# Plot the heatmap using seaborn
plt.figure(figsize=(18, 5))  # Adjusted figure size
sns.heatmap(heatmap_data, annot=True, fmt=".3f", cmap="coolwarm", cbar_kws={'label': 'Values'})

main_title = f"Energy consumption (joules per image)"
plt.title(main_title, fontsize=16)
plt.title(main_title, fontsize=16, y=1.08)  # Adjust the `y` parameter here

# Adding subtitles at specific x-coordinates below the main title
title_x_coords = [0.13, 0.32, 0.5, 0.7]
subtitles = ["Resolution: 160x160", "Resolution: 320x320", "Resolution: 640x640", "Resolution: 1280x1280"]

for x, subtitle in zip(title_x_coords, subtitles):
    plt.figtext(x, 0.88, subtitle, ha="center", fontsize=12, color='grey')

# Modify x-labels to add prefix "v"
new_labels = ['v' + lbl.get_text().split('-')[-1] for lbl in plt.gca().get_xticklabels()]
plt.gca().set_xticklabels(new_labels)
plt.xlabel("YOLO Version")
plt.ylabel("Model Size")
plt.tight_layout()
plt.savefig("yolo_joules_per_image_table.png")
plt.show()

# %%
from matplotlib.colors import LogNorm

# Adjusted style
# Plot the heatmap using seaborn
main_title = f"Energy consumption (joules per image)"
# Plot the heatmap using seaborn
plt.figure(figsize=(14, 3))  # Adjusted figure size

# Adjust subplot parameters for minimal white space
plt.subplots_adjust(left=0.06, right=0.92, top=0.75, bottom=0.15)

sns.heatmap(heatmap_data, annot=True, fmt=".3f", cmap="coolwarm",
            norm=LogNorm(), cbar_kws={'label': 'Values (log scale)', 'shrink': 0.9, 'aspect': 15, 'pad': 0.01})

plt.title(main_title, fontsize=16, y=1.15, pad=0)  # Adjust the `y` parameter here

# Adding subtitles at specific x-coordinates below the main title
title_x_coords = [0.15, 0.33, 0.52, 0.70]  # Adjusted for new layout
subtitles = ["Resolution: 160x160", "Resolution: 320x320", "Resolution: 640x640", "Resolution: 1280x1280"]

for x, subtitle in zip(title_x_coords, subtitles):
    plt.figtext(x, 0.77, subtitle, ha="center", fontsize=12, color='grey', weight='bold')

# Modify x-labels to add prefix "v"
new_labels = ['v' + lbl.get_text().split('-')[-1] for lbl in plt.gca().get_xticklabels()]
plt.gca().set_xticklabels(new_labels)
plt.gca().set_xticklabels(new_labels, fontsize=12)
plt.gca().set_yticklabels(plt.gca().get_yticklabels(), fontsize=12)
plt.xlabel("YOLO Version", fontsize=14)
plt.ylabel("Model Size", fontsize=14)

# Remove margins and save with no padding
plt.margins(0)
plt.savefig("yolo_joules_per_image_table.png", bbox_inches='tight', pad_inches=0, dpi=300)
plt.savefig("yolo_joules_per_image_table.pdf", bbox_inches='tight', pad_inches=0)
plt.show()
